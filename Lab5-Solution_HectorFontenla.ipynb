# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import dataset
data = pd.read_csv('/Users/Hector_Martin/Documents/Labs/lab-customer-analysis-round-3/files_for_lab/csv_files/marketing_customer_analysis.csv')
datasafe = data.copy()
datasafe.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
#Show DataFrame info.
datasafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
#Describe DataFrame.
datadescr = datasafe.describe().T
datadescr.head()
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# Months Since Policy Inception     0.000000    24.000000     48.000000
#
#                                         75%          max
# Customer Lifetime Value         8962.167041  83325.38119
# ...

# %%
def round2(x):
    x = round(x, 2)
    return x

# %%
for column in datadescr.columns:
    #datadescr[column] = datadescr[column].apply(lambda x : round(x, 2))
    datadescr[column] = datadescr[column].apply(round2)
    
datadescr.head()
# Out:
#                                 count      mean       std      min      25%  \
# Customer Lifetime Value        9134.0   8004.94   6870.97  1898.01  3994.25
# Income                         9134.0  37657.38  30379.90     0.00     0.00
# Monthly Premium Auto           9134.0     93.22     34.41    61.00    68.00
# Months Since Last Claim        9134.0     15.10     10.07     0.00     6.00
# Months Since Policy Inception  9134.0     48.06     27.91     0.00    24.00
#
#                                     50%       75%       max
# Customer Lifetime Value         5780.18   8962.17  83325.38
# Income                         33889.50  62320.00  99981.00
# Monthly Premium Auto              83.00    109.00    298.00
# Months Since Last Claim           14.00     23.00     35.00
# Months Since Policy Inception     48.00     71.00     99.00

# %%
#Show a plot of the total number of responses.
ax = sns.countplot(x="Response", hue="Response", data=datasafe, palette='Set1')

# %%
#Show a plot of the response rate by the sales channel.
ax = sns.countplot(x="Sales Channel", hue="Response", data=datasafe, palette ='Set2')
#hue identifies the unique values of a column, categorizes and 
#counts the total amount per category

# %%
#Show a plot of the response rate by the total claim amount.

ax3 = sns.stripplot(x="Total Claim Amount", y="Response", palette="Set1", data=datasafe)

# %%
#Show a plot of the response rate by income.

ax4 = sns.stripplot(x="Income", y="Response", palette="Set2", data=datasafe)

# %% [markdown]
# **Lab 4**

# %%
#Check the data types of the columns.

datasafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
#Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. 
#(You can use np.number and np.object to select the numerical data types and categorical data types respectively)

numerical = datasafe.select_dtypes(include=np.number)
categorical = datasafe.select_dtypes(include=np.object)

display(numerical.head())
display(categorical.head())
# Out:
# /var/folders/vn/08z_mvy95tzdstqgmlzmj2fc0000gn/T/ipykernel_21502/2764401450.py:5: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = datasafe.select_dtypes(include=np.object)
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# ...

# %%
numerical.columns
# Out:
# Index(['Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies',
#        'Total Claim Amount'],
#       dtype='object')

# %%
#Now we will try to check the normality of the numerical variables visually
#Use seaborn library to construct distribution plots for the numerical variables
import numpy as np
import pandas as pd
import seaborn as sns

sns.displot(numerical['Customer Lifetime Value'], kde=True)
sns.displot(numerical['Income'], kde=True)
sns.displot(numerical['Monthly Premium Auto'], kde=True)
sns.displot(numerical['Months Since Last Claim'], kde=True)
sns.displot(numerical['Months Since Policy Inception'], kde=True)
sns.displot(numerical['Number of Open Complaints'], kde=True)
sns.displot(numerical['Number of Policies'], kde=True)
sns.displot(numerical['Total Claim Amount'], kde=True)

plt.show()

#Do the distributions for different numerical variables look like a normal distribution?
#Nope

# %%
#Use Matplotlib to construct histograms
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

fig, ax = plt.subplots(2,4, figsize=(15,10))
ax[0,0].set_title('Income')
ax[0,0].hist(numerical['Income'])

ax[0,1].set_title('Customer Lifetime Value')
ax[0,1].hist(numerical['Customer Lifetime Value'])

ax[0,2].set_title('Monthly Premium Auto')
ax[0,2].hist(numerical['Monthly Premium Auto'])

ax[0,3].set_title('Months Since Last Claim')
ax[0,3].hist(numerical['Months Since Last Claim'])

ax[1,0].set_title('Number of Open Complaints')
ax[1,0].hist(numerical['Number of Open Complaints'])

ax[1,1].set_title('Number of Policies')
ax[1,1].hist(numerical['Number of Policies'])

ax[1,2].set_title('Total Claim Amount')
ax[1,2].hist(numerical['Total Claim Amount'])

ax[1,3].set_title('Months Since Policy Inception')
ax[1,3].hist(numerical['Months Since Policy Inception'])
# Out:
# (array([ 878.,  958.,  938.,  984.,  960., 1000.,  948.,  944.,  801.,
#          723.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
#For the numerical variables, check the multicollinearity between the features. 
#Please note that we will use the column total_claim_amount later as the target variable.
#Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 

corr_num = numerical.corr()
sns.heatmap(corr_num, annot=True) #annot = displays the correlation values, = false hides them
plt.show()

# %%
#If there is no pair of features that have a high correlation, then do not drop any features
#Nothing to drop

# %% [markdown]
# **LAB 5**

# %%
#Get the data
#We are using the marketing_customer_analysis.csv file.

# %%
#Dealing with the data
#Already done in the round 2.

# %%
#Explore the data
#Done in the round 3.

# %%
#Processing Data
#(Further processing...)

#X-y split.
y = numerical['Total Claim Amount']
X= numerical.drop(['Total Claim Amount'], axis=1)

# %%
#Normalize (numerical).
from sklearn.preprocessing import MinMaxScaler

transformer = MinMaxScaler().fit(X)
x_normalized = transformer.transform(X)
print(x_normalized.shape)
x_normalized
pd.DataFrame(x_normalized, columns=X.columns)
# Out:
# (9134, 7)
#       Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                    0.010629  0.562847              0.033755
# 1                    0.062406  0.000000              0.139241
# 2                    0.134960  0.487763              0.198312
# 3                    0.070589  0.000000              0.189873
# 4                    0.011245  0.438443              0.050633
# ...                       ...       ...                   ...
# 9129                 0.264137  0.719547              0.050633
# 9130                 0.014719  0.216081              0.075949
# 9131                 0.076951  0.000000              0.101266
# 9132                 0.069098  0.219452              0.147679
# 9133                 0.008766  0.000000              0.067511
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                    0.914286                       0.050505
# 1                    0.371429                       0.424242
# ...
